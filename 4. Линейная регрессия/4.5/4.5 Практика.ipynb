# %% [markdown]
# # Практика. Обучение модели с помощью sklearn

# %% [markdown]
# ```
# # Выбран кодовый формат
# ```
#
# ##Цели задания
#
# - Научиться строить модель линейной регрессии.
# - Познакомиться с функционалом библиотеки Scikit-learn.

# %% [markdown]
# ## Что нужно сделать
#
# - Загрузить данные и ознакомиться с ними.
# - Разделить данные на обучающую и тестовую выборки.
# - Реализовать построение модели с помощью  библиотеки Scikit-learn.
# - Получить качество модели с помощью MSE и MAE.
# - Дополнить данные переменной.
# - Реализовать построение новой модели с помощью  библиотеки Scikit-learn.
# - Получить качество новой модели с помощью MSE и MAE.
# - Сравнить полученные модели и сделать выводы.

# %% [markdown]
# Обратите внимание, что задание не нужно сдавать на проверку.
# После выполнения задания рекомендуем свериться с ответами, представленными ниже.

# %% [markdown]
# ## Задача

# %% [markdown]
# Подключите библиотеки.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Инициализируйте данные.
#
# Пусть нам заданы 1000 точек — это матрица **X**, и есть целевая функция **Y**.

# %%
np.random.seed(0) # для воспроизведения результатов
x = np.random.rand(1000, 1)
y = 1 + 5 * x + 15 * x ** 2 + np.random.randn(1000, 1)

d = {'x': x.reshape(1,1000)[0], 'y': y.reshape(1,1000)[0]}
df = pd.DataFrame(data=d)
df.head()
# Out:
#           x          y
# 0  0.548814   8.160314
# 1  0.715189  12.267664
# 2  0.602763  11.313263
# 3  0.544883   7.963715
# 4  0.423655   5.311508

# %%
plt.scatter(df['x'], df['y'], s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### 1. Найдите заданную зависимость с помощью линейной регресии

# %% [markdown]
# Разделите исходные данные на обучающую и тестовую выборки в соотношении 70% и 30%.

# %%
# подключить библиотеку для разделения на обучающую и тестовую выборки

# Ваш код здесь
from sklearn.model_selection import train_test_split

# %%
# разделить исходные данные на обучающую и тестовую выборки

# Ваш код здесь
train, test = train_test_split(df, train_size=0.7, random_state=63)

# %% [markdown]
# Для построения самой модели подключите необходимый функционал из `sklearn`.

# %%
# Ваш код здесь
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Создайте экземпляр класса `LinearRegression`, который будет содержать в себе модель регрессии.

# %%
# Ваш код здесь
model = LinearRegression()

# %% [markdown]
# Чтобы обучить модель, необходимо вызвать метод `.fit()` на объект `model`. В качестве аргументов здесь передаются матрица **X** и целевая функция **Y**. Обучать модель будем на обучающей выборке.

# %%
# Ваш код здесь
model.fit(train[['x']], train[['y']])
# Out:
# LinearRegression()

# %% [markdown]
# Поздравляем, модель готова!

# %% [markdown]
# Проанализируйте коэффициенты полученной модели.

# %%
# Ваш код здесь
print('w_0:', model.intercept_)
print('w_1:', model.coef_)
# Out:
# w_0: [-1.59564162]
# w_1: [[20.15187903]]

# %% [markdown]
# Запишите полученное уравнение модели линейной регрессии.

# %% [markdown]
# y* = -1.59 + 20.15*x1
# y = 1 + 5 * x + 15 * x ** 2

# %% [markdown]
# Посмотрите на графике, какую модель получили. Для этого создайте переменную `y_predict_train` и заполните её предсказанными значениями по обучающей выборке.

# %%
# Ваш код здесь
# y_predict_train = ......
y_predict_train = model.predict(train[['x']])
print(y_predict_train[:, 0][:10])
# Out:
# [ 5.0139329  18.36167106 14.8039136  12.30448502  2.43466416 17.08941856
#  17.28902765  5.75801756 17.90723954 10.96491724]

# %%
# расскомментируйте код перед запуском
# если меняли названия объектов, то здесь также нужно их заменить

plt.plot(train['x'], y_predict_train, linewidth=4, c='g')
plt.scatter(train['x'], train['y'], s=10, c='b')
plt.scatter(test['x'], test['y'], s=10, c='r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Получите результаты предсказания модели по тестовой выборке.

# %%
# Ваш код здесь
# y_predict_test = ......
y_predict_test = model.predict(test[['x']])
y_predict_test
# Out:
# array([[ 5.81879048e+00],
#        [ 1.80629497e+01],
#        [ 1.59899088e+01],
#        [ 3.87059742e+00],
#        [ 1.65504827e+00],
#        [ 6.94179865e+00],
#        [ 1.68819626e+00],
#        [ 7.07777628e+00],
#        [-3.06822832e-01],
#        [ 1.74539605e+01],
#        [-3.64794328e-01],
#        [ 1.25001801e+01],
#        [-1.21699183e+00],
#        [ 6.87777045e-03],
#        [ 1.79171490e+01],
#        [ 1.84434028e+01],
#        [ 8.23960951e+00],
#        [ 1.17080957e+01],
#        [ 1.52905228e+01],
#        [ 6.31535712e+00],
#        [ 6.42926106e+00],
#        [ 9.46398173e+00],
#        [ 1.03351158e+01],
#        [ 1.28396975e+01],
#        [ 1.73513503e+01],
#        [ 1.02921529e+01],
#        [ 1.58635902e+01],
#        [ 8.68215630e+00],
#        [ 7.31220708e+00],
#        [ 1.63782899e+01],
#        [ 1.65644694e+01],
#        [ 2.05489065e+00],
#        [ 1.71621046e+01],
#        [ 1.61729827e+01],
#        [ 7.10513625e+00],
#        [ 1.63752600e+01],
#        [ 5.11638573e+00],
#        [ 1.38271003e+01],
#        [ 5.36384368e+00],
#        [ 9.63638684e+00],
#        [ 7.96945012e-01],
#        [ 9.38477837e+00],
#        [ 1.35388558e+01],
#        [ 4.78328576e+00],
#        [ 5.57062326e+00],
#        [ 1.10543933e+01],
#        [ 6.24615332e+00],
#        [ 5.11785919e+00],
#        [ 1.06243211e+01],
#        [ 1.15657184e+01],
#        [ 1.66213337e+01],
#        [ 1.63951731e+00],
#        [ 1.31150399e+01],
#        [ 1.58818696e+01],
#        [ 9.68301052e+00],
#        [ 1.74226555e+01],
#        [ 1.15454646e+01],
#        [ 3.85197363e+00],
#        [ 1.55121662e+01],
#        [-4.48246078e-02],
#        [ 7.39930306e-01],
#        [ 1.33019086e+01],
#        [ 7.40976890e+00],
#        [ 7.53505881e+00],
#        [ 8.28802496e+00],
#        [-7.89711512e-01],
#        [ 3.61131545e-01],
#        [ 1.68405687e+01],
#        [ 1.75678404e+01],
#        [ 1.23335892e+00],
#        [ 1.85416876e+01],
#        [ 5.42680436e+00],
#        [ 2.89987246e+00],
#        [ 1.05784673e+01],
#        [ 1.07769261e+01],
#        [-1.64131567e-01],
#        [ 1.26257418e+01],
#        [ 1.07547751e+01],
#        [ 1.40859782e+01],
#        [ 1.31324762e+01],
#        [ 2.92476801e+00],
#        [ 9.85152366e+00],
#        [ 7.38631164e-01],
#        [ 1.88965315e+00],
#        [ 2.15649731e+00],
#        [ 1.28860305e+01],
#        [ 3.61732841e+00],
#        [-1.26659161e+00],
#        [ 6.11866008e+00],
#        [ 7.35995944e-01],
#        [ 1.86752125e+00],
#        [-1.09831887e+00],
#        [ 1.20500248e+01],
#        [ 1.79616299e+01],
#        [ 1.76040412e+01],
#        [ 1.61685937e+00],
#        [-1.17948518e+00],
#        [ 5.73057358e-01],
#        [-1.20886261e+00],
#        [ 1.92405304e+00],
#        [ 5.94458656e+00],
#        [ 1.60251597e+01],
#        [ 1.60137187e+01],
#        [ 1.49715755e+01],
#        [ 5.36694657e+00],
#        [ 1.00348188e+01],
#        [-1.84159875e-01],
#        [ 7.36362763e+00],
#        [ 7.88825391e+00],
#        [ 4.89998485e+00],
#        [ 1.51283498e+01],
#        [ 1.04236054e+01],
#        [ 8.70839667e+00],
#        [ 1.23249696e+01],
#        [ 6.87901884e+00],
#        [ 2.98613895e+00],
#        [ 1.65020024e+01],
#        [ 2.77470143e+00],
#        [ 6.28624875e-01],
#        [-9.92086294e-01],
#        [ 1.21180039e+01],
#        [ 1.92634267e+00],
#        [ 3.48024459e-01],
#        [ 7.04485338e+00],
#        [ 1.69914033e+01],
#        [ 5.60556947e+00],
#        [ 4.24665915e+00],
#        [ 9.19836584e+00],
#        [ 8.77275695e+00],
#        [ 4.08174939e+00],
#        [ 1.31815123e+01],
#        [ 7.39482727e+00],
#        [ 3.19530290e+00],
#        [ 8.32636589e+00],
#        [ 1.76777308e+01],
#        [ 1.40705815e+01],
#        [ 1.69147954e+01],
#        [ 3.73565107e+00],
#        [ 1.44598017e+00],
#        [ 1.61516774e+01],
#        [ 1.47459198e+00],
#        [-1.50101895e+00],
#        [ 7.98837274e+00],
#        [ 3.53011943e+00],
#        [ 3.19662117e+00],
#        [ 1.05033901e+01],
#        [ 1.81629869e+01],
#        [ 1.51515463e+01],
#        [ 3.36299392e+00],
#        [ 9.89022232e+00],
#        [ 1.19189716e+01],
#        [ 1.30726725e+01],
#        [ 1.31503787e+01],
#        [ 1.63808293e+00],
#        [ 8.84605075e+00],
#        [ 1.85330024e+01],
#        [ 1.21443186e+01],
#        [ 1.64542209e+01],
#        [ 7.58241379e+00],
#        [ 1.75053406e+00],
#        [ 1.83219484e+01],
#        [ 1.15675823e+01],
#        [ 8.02983293e+00],
#        [ 1.38967509e+00],
#        [ 1.38050029e+00],
#        [ 7.13168275e+00],
#        [ 6.94940503e+00],
#        [ 1.05511730e+01],
#        [ 1.77942656e+01],
#        [ 9.58149851e+00],
#        [ 1.77669822e+01],
#        [ 6.02670939e+00],
#        [ 3.84552640e+00],
#        [ 4.10128755e+00],
#        [ 1.66997575e+01],
#        [ 4.10345008e+00],
#        [ 1.25890360e+01],
#        [ 1.28167680e+01],
#        [ 1.02600537e+01],
#        [-1.25564570e+00],
#        [ 9.06258483e+00],
#        [ 1.60675861e+01],
#        [-6.01167612e-01],
#        [ 1.80702520e+01],
#        [ 4.69063620e+00],
#        [ 3.34896871e+00],
#        [ 8.43549841e+00],
#        [-1.43676212e+00],
#        [ 7.41477492e+00],
#        [ 6.30679758e-01],
#        [ 2.86116639e+00],
#        [ 1.77891839e+01],
#        [ 8.50172283e+00],
#        [ 7.63671661e+00],
#        [ 1.54610836e+01],
#        [ 1.47889215e+01],
#        [ 1.25755123e+01],
#        [-3.21889340e-01],
#        [ 1.32340032e+01],
#        [ 1.07423317e+00],
#        [ 1.23533785e-01],
#        [ 1.00107625e+01],
#        [ 1.72631333e+01],
#        [ 3.28471212e+00],
#        [ 1.32198994e+01],
#        [ 5.93739552e+00],
#        [-9.86344357e-01],
#        [ 3.91674438e+00],
#        [ 1.27881020e+01],
#        [ 1.23198980e+00],
#        [ 1.48274643e+01],
#        [ 1.12504211e+01],
#        [-1.51784828e+00],
#        [ 1.70106953e+01],
#        [ 1.63353725e+01],
#        [ 4.37213982e+00],
#        [ 1.79106834e+01],
#        [ 1.03146610e+01],
#        [ 1.59724791e+01],
#        [ 9.22436575e+00],
#        [ 1.23888840e+01],
#        [ 9.52977303e+00],
#        [ 1.02216251e+01],
#        [ 1.81027222e+01],
#        [ 4.98799503e+00],
#        [-9.29126452e-01],
#        [ 7.65346348e+00],
#        [ 1.83428245e+01],
#        [ 8.25005762e-01],
#        [ 8.14815720e+00],
#        [ 1.70441797e+01],
#        [ 1.76049006e+01],
#        [ 2.37537240e+00],
#        [ 1.43622197e+01],
#        [ 1.60081699e+01],
#        [ 8.99563698e-01],
#        [ 4.53453362e+00],
#        [-1.49179971e+00],
#        [ 1.42266649e+01],
#        [ 5.63878780e+00],
#        [ 6.60986693e+00],
#        [ 1.50671734e+01],
#        [ 7.54720231e+00],
#        [ 9.84752231e+00],
#        [ 4.53402712e+00],
#        [-3.33408462e-01],
#        [ 1.53878958e+01],
#        [ 9.89489472e+00],
#        [ 1.48015121e+01],
#        [-2.73580270e-01],
#        [ 2.89548308e+00],
#        [-9.24490813e-01],
#        [-1.26455371e+00],
#        [ 8.98349923e+00],
#        [ 2.71354242e+00],
#        [-1.28115010e+00],
#        [ 1.82222451e+01],
#        [-5.42895012e-02],
#        [ 5.16527691e+00],
#        [ 1.61213531e+01],
#        [ 4.82412138e+00],
#        [ 7.29781526e+00],
#        [ 1.29420583e+01],
#        [ 1.53155961e+01],
#        [-6.96619920e-01],
#        [ 1.30657973e+01],
#        [ 5.60692871e-01],
#        [ 1.01142511e+01],
#        [ 1.69341604e+01],
#        [ 1.16505697e+01],
#        [ 1.12766080e+01],
#        [ 2.98719046e+00],
#        [ 1.60789420e+00],
#        [ 1.39388929e+01],
#        [ 8.97159690e+00],
#        [-4.50046059e-01],
#        [ 8.52844996e+00],
#        [ 1.61052147e+01],
#        [ 5.00854027e+00],
#        [ 1.45217483e+01],
#        [ 1.58547867e+01],
#        [ 1.29319649e+00],
#        [ 4.12749156e+00],
#        [-4.79745012e-01],
#        [ 1.12909312e+01],
#        [ 1.69336608e+01],
#        [ 1.58987297e+01],
#        [ 1.19339970e+01],
#        [ 1.09385780e+00],
#        [ 1.46733524e+01],
#        [ 3.10821513e+00],
#        [ 5.44623688e+00],
#        [ 8.85986154e+00],
#        [ 1.27189802e+01],
#        [ 8.92058264e+00],
#        [ 1.81053792e+00],
#        [ 1.67889635e+00],
#        [ 1.33144096e+01],
#        [ 1.79309590e+01],
#        [ 6.67270584e+00]])

# %% [markdown]
# Оцените качество модели с помощью MSE.

# %%
# Ваш код здесь
from sklearn.metrics import mean_squared_error

train_mse = mean_squared_error(train[['y']], y_predict_train)
test_mse = mean_squared_error(test[['y']], y_predict_test)
print("Train MSE: {}".format(train_mse))
print("Test MSE: {}".format(test_mse))
# Out:
# Train MSE: 2.2260149216864926
# Test MSE: 2.7333850985072687

# %% [markdown]
# Оцените также качество модели с помощью MAE.

# %%
# Ваш код здесь
from sklearn.metrics import mean_absolute_error

train_mae = mean_absolute_error(train[['y']], y_predict_train)
test_mae = mean_absolute_error(test[['y']], y_predict_test)
print("Train MAE: {}".format(train_mae))
print("Test MAE: {}".format(test_mae))
# Out:
# Train MAE: 1.1975908469197953
# Test MAE: 1.317375901979988

# %% [markdown]
# ### 2. Дополните данные переменной `x2 = x**2` и постройте модель с использованием двух переменных

# %%
# Ваш код здесь
df['x2'] = df['x'].apply(lambda x: x**2)
train, test = train_test_split(df, train_size=0.7, random_state=63)
model = LinearRegression()
model.fit(train[['x', 'x2']], train[['y']])
y_predict_train = model.predict(train[['x', 'x2']])
y_predict_test = model.predict(test[['x', 'x2']])
df
# Out:
#             x          y        x2
# 0    0.548814   8.160314  0.301196
# 1    0.715189  12.267664  0.511496
# 2    0.602763  11.313263  0.363324
# 3    0.544883   7.963715  0.296898
# 4    0.423655   5.311508  0.179483
# ..        ...        ...       ...
# 995  0.097676   1.621835  0.009541
# 996  0.514922   5.754620  0.265145
# 997  0.938412  18.099064  0.880617
# 998  0.228647   3.120635  0.052279
# 999  0.677141  12.560850  0.458520
#
# [1000 rows x 3 columns]

# %%
print('w_0:', model.intercept_)
print('w_1, w_2:', model.coef_)
# Out:
# w_0: [1.101502]
# w_1, w_2: [[ 4.58684506 15.34846108]]

# %% [markdown]
# Полученная модель имеет вид y = -1.01 + 4.58* x + 15.34 * x ** 2
#
# Напомним, что исходная модель — y = 1 + 5 * x + 15 * x ** 2

# %% [markdown]
# Посмотрите на графике, какую модель мы получили.

# %%
# расскомментируйте код перед запуском
# если меняли названия объектов, то здесь также нужно их заменить

plt.plot(train['x'], y_predict_train, linewidth=4, c='g')
plt.scatter(train['x'], train['y'], s=10, c='b')
plt.scatter(test['x'], test['y'], s=10, c='r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Оцените качество модели с помощью MSE.

# %%
# Ваш код здесь
train_mse = mean_squared_error(train[['y']], y_predict_train)
test_mse = mean_squared_error(test[['y']], y_predict_test)
print("Train MSE: {}".format(train_mse))
print("Test MSE: {}".format(test_mse))
# Out:
# Train MSE: 0.9538697555120436
# Test MSE: 0.8738331579237119

# %% [markdown]
# Оцените также качество модели с помощью MAE.

# %%
# Ваш код здесь
train_mae = mean_absolute_error(train[['y']], y_predict_train)
test_mae = mean_absolute_error(test[['y']], y_predict_test)
print("Train MAE: {}".format(train_mae))
print("Test MAE: {}".format(test_mae))
# Out:
# Train MAE: 0.7673507063479954
# Test MAE: 0.7623816155961576

# %% [markdown]
# ### 3. Сделайте выводы по результатам построения моделей

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# |

# %% [markdown]
# ## Ответы для самостоятельной проверки

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.random.seed(0) # для воспроизведения результатов
x = np.random.rand(1000, 1)
y = 1 + 5 * x + 15 * x ** 2 + np.random.randn(1000, 1)

d = {'x': x.reshape(1,1000)[0], 'y': y.reshape(1,1000)[0]}
df = pd.DataFrame(data=d)
df.head()
# Out:
#           x          y
# 0  0.548814   8.160314
# 1  0.715189  12.267664
# 2  0.602763  11.313263
# 3  0.544883   7.963715
# 4  0.423655   5.311508

# %%
plt.scatter(df['x'], df['y'], s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Построим модель линейной регресии, предварительно разделив выборку на `train` и `test`.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, train_size=0.7, random_state=123) # random_state нужен для воспроизводимости результата

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(train[['x']], train[['y']])
# Out:
# LinearRegression()

# %%
# коэффициенты модели
print('w_0:', model.intercept_)
print('w_1:', model.coef_)
# Out:
# w_0: [-1.40630312]
# w_1: [[19.9722818]]

# %% [markdown]
# Полученная модель имеет вид `y = -1.4 + 19.9 * x1`
#
# Напомним, что исходная модель — `y = 1 + 5 * x + 15 * x ** 2`

# %%
y_predict_train = model.predict(train[['x']])
y_predict_test = model.predict(test[['x']])

# %%
plt.scatter(train['x'], train['y'], s=10, c='b')
plt.scatter(test['x'], test['y'], s=10, c='r')
plt.scatter(train['x'], y_predict_train, s=10, c='g')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Посмотрим на качество модели.

# %%
from sklearn.metrics import mean_squared_error

train_mse = mean_squared_error(train[['y']], y_predict_train)
test_mse = mean_squared_error(test[['y']], y_predict_test)
print("Train MSE: {}".format(train_mse))
print("Test MSE: {}".format(test_mse))
# Out:
# Train MSE: 2.4035940932759727
# Test MSE: 2.3078508257662658

# %%
from sklearn.metrics import mean_absolute_error

train_mae = mean_absolute_error(train[['y']], y_predict_train)
test_mae = mean_absolute_error(test[['y']], y_predict_test)
print("Train MAE: {}".format(train_mae))
print("Test MAE: {}".format(test_mae))
# Out:
# Train MAE: 1.249117275460529
# Test MAE: 1.2250964333659067

# %% [markdown]
# Как вы уже знаете, задача машинного обучения — найти наиболее оптимальную модель. Попробуем улучшить нашу модель, добавив переменную квадрата переменной `x`.

# %%
df['x2'] = df['x'].apply(lambda x: x ** 2)

# %%
train, test = train_test_split(df, train_size=0.7, random_state=123) # random_state нужен для воспроизводимости результата

# %% [markdown]
# Обратите внимание, что здесь и далее будем использовать уже две переменных: `x` и `x2`.

# %%
model = LinearRegression()
model.fit(train[['x', 'x2']], train[['y']])
# Out:
# LinearRegression()

# %%
# коэффициенты модели
print('w_0:', model.intercept_)
print('w_1, w_2:', model.coef_)
# Out:
# w_0: [1.23205489]
# w_1, w_2: [[ 3.93880839 15.90084072]]

# %% [markdown]
# Полученная модель имеет вид `y = 1.2 + 3.9 * x + 15.9 * x**2`
#
# Напомним, что исходная модель — `y = 1 + 5 * x + 15 * x**2`

# %%
y_predict_train = model.predict(train[['x', 'x2']])
y_predict_test = model.predict(test[['x', 'x2']])

# %%
plt.scatter(train['x'], train['y'], s=10, c='b')
plt.scatter(test['x'], test['y'], s=10, c='r')
plt.scatter(train['x'], y_predict_train, s=10, c='g')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Видим, что график уже выглядит лучше. Оценим качество.

# %%
train_mse = mean_squared_error(train[['y']], y_predict_train)
test_mse = mean_squared_error(test[['y']], y_predict_test)
print("Train MSE: {}".format(train_mse))
print("Test MSE: {}".format(test_mse))
# Out:
# Train MSE: 0.9553345559754468
# Test MSE: 0.8643319642042345

# %%
from sklearn.metrics import mean_absolute_error

train_mae = mean_absolute_error(train[['y']], y_predict_train)
test_mae = mean_absolute_error(test[['y']], y_predict_test)
print("Train MAE: {}".format(train_mae))
print("Test MAE: {}".format(test_mae))
# Out:
# Train MAE: 0.781313778676075
# Test MAE: 0.7273715175787049

# %% [markdown]
# **Вывод:** в результате добавление переменной квадрата `x` позволило улучшить качество модели, то есть снизить ошибку.
